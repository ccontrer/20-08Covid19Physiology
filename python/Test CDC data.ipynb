# %%
import numpy as np
import pandas as pd

# %%
DF = pd.read_csv("../../data/CDC/COVID_Cases_Restricted_Detailed_12042020.csv",
                 na_values=['NaN','nan','Unknown','Missing'],
                 nrows=10000)

# %%
DF.shape
# Out:
# (10000, 31)

# %%
DF.head(10)
# Out:
#   race_ethnicity_combined             current_status cdc_report_dt     sex  \
# 0                     NaN  Laboratory-confirmed case    2020-09-15  Female
# 1                     NaN  Laboratory-confirmed case    2020-09-27  Female
# 2                     NaN  Laboratory-confirmed case    2020-09-13  Female
# 3                     NaN  Laboratory-confirmed case    2020-07-31  Female
# 4                     NaN  Laboratory-confirmed case    2020-10-01  Female
# 5                     NaN  Laboratory-confirmed case    2020-10-08  Female
# 6                     NaN  Laboratory-confirmed case    2020-10-11  Female
# 7                     NaN  Laboratory-confirmed case    2020-08-17     NaN
# 8                     NaN              Probable Case    2020-10-30     NaN
# 9                     NaN  Laboratory-confirmed case    2020-08-16     NaN
#
#      onset_dt pos_spec_dt hosp_yn icu_yn death_yn hc_work_yn  ... sob_yn  \
# ...

# %%
DF['current_status'].value_counts()
# Out:
# Laboratory-confirmed case    9432
# Probable Case                 568
# Name: current_status, dtype: int64

# %%
DF['race_ethnicity_combined'].value_counts()
# Out:
# White, Non-Hispanic                                     3477
# Hispanic/Latino                                         2575
# Black, Non-Hispanic                                     1068
# Multiple/Other, Non-Hispanic                             145
# Asian, Non-Hispanic                                      130
# American Indian/Alaska Native, Non-Hispanic              114
# Native Hawaiian/Other Pacific Islander, Non-Hispanic       8
# Name: race_ethnicity_combined, dtype: int64

# %%
DF['age_group'].value_counts()
# Out:
# 10 - 19 Years    3366
# 20 - 29 Years    2043
# 30 - 39 Years    1030
# 50 - 59 Years    1021
# 60 - 69 Years     832
# 40 - 49 Years     804
# 70 - 79 Years     482
# 80+ Years         228
# 0 - 9 Years       104
# Name: age_group, dtype: int64

# %%
pd.read_csv?
